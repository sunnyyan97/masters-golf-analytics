# %%
import duckdb
import pandas as pd

conn = duckdb.connect('data/masters.duckdb')

# See all tables
conn.execute("SHOW TABLES").df()
# Out:
#                              name
# 0           int_augusta_career_sg
# 1           int_augusta_fit_score
# 2   int_augusta_regression_inputs
# 3             int_driving_profile
# 4                int_player_sigma
# 5           int_recent_trajectory
# 6        mart_backtest_comparison
# 7        mart_player_model_inputs
# 8         mart_simulation_results
# 9              stg_approach_skill
# 10                stg_dg_rankings
# 11         stg_masters_field_2026
# 12             stg_masters_rounds
# 13      stg_player_decompositions
# 14                stg_player_list
# 15               stg_pred_archive
# 16              stg_skill_ratings

# %%
conn.execute("""
    SELECT player_name, win_pct, top5_pct, top10_pct, mc_pct
    FROM mart_simulation_results
    where model_type = 'regression'
    ORDER BY win_pct DESC
    
    LIMIT 50
""").df()
# Out:
#            player_name  win_pct  top5_pct  top10_pct   mc_pct
# 0        McIlroy, Rory  0.10629   0.30854    0.45048  0.17330
# 1   Scheffler, Scottie  0.10313   0.38761    0.59081  0.06712
# 2   DeChambeau, Bryson  0.07218   0.23542    0.36189  0.22478
# 3            Rahm, Jon  0.06962   0.25693    0.41382  0.16501
# 4   Schauffele, Xander  0.05369   0.23510    0.40053  0.14671
# 5    Matsuyama, Hideki  0.03585   0.15359    0.26766  0.25912
# 6       Young, Cameron  0.03335   0.13815    0.23669  0.30495
# 7     Cantlay, Patrick  0.03105   0.13513    0.23807  0.29205
# 8    Fitzpatrick, Matt  0.02876   0.16218    0.31170  0.17051
# 9         Rose, Justin  0.02384   0.10206    0.18332  0.35798
# 10     Hovland, Viktor  0.02310   0.11944    0.23006  0.26414
# 11     Henley, Russell  0.02121   0.10121    0.19174  0.32675
# 12      Thomas, Justin  0.02113   0.09975    0.18729  0.33323
# 13       Aberg, Ludvig  0.01996   0.13358    0.27556  0.18029
# ...

# %%
conn.execute("""
    SELECT player_name, win_pct, top5_pct, top10_pct, mc_pct
    FROM mart_simulation_results
    where model_type = 'manual'
    ORDER BY win_pct DESC
    LIMIT 20
""").df()
# Out:
#            player_name  win_pct  top5_pct  top10_pct   mc_pct
# 0   Scheffler, Scottie  0.08844   0.33669    0.52706  0.08969
# 1        McIlroy, Rory  0.07999   0.24458    0.36793  0.22315
# 2   DeChambeau, Bryson  0.06071   0.19667    0.30724  0.26654
# 3        Aberg, Ludvig  0.05035   0.23490    0.40697  0.12998
# 4            Rahm, Jon  0.04895   0.18993    0.31878  0.22143
# 5       Young, Cameron  0.04772   0.16608    0.27067  0.28714
# 6   Schauffele, Xander  0.03342   0.16065    0.29489  0.20707
# 7     Cantlay, Patrick  0.02594   0.11285    0.20035  0.33904
# 8    Hojgaard, Nicolai  0.02276   0.10821    0.20169  0.30272
# 9    Matsuyama, Hideki  0.02257   0.10179    0.18585  0.33646
# 10        Rose, Justin  0.02105   0.08588    0.15558  0.39792
# 11    Hojgaard, Rasmus  0.02034   0.09946    0.18846  0.31623
# 12          Day, Jason  0.01952   0.08202    0.14799  0.41358
# 13   McNealy, Maverick  0.01855   0.09481    0.18327  0.32144
# ...

# %%
import os
os.getcwd()
# Out:
# '/Users/sunnyyan/Projects/masters-golf-analytics'

# %%
coefs = weights['coefficients']
sorted_coefs = sorted(coefs.items(), key=lambda x: abs(x[1]), reverse=True)

print("Feature coefficients (sorted by absolute magnitude):\n")
for feature, coef in sorted_coefs:
    bar = '█' * min(int(abs(coef) * 3), 40)
    print(f"{feature:25s}: {coef:+.4f}  {bar}")

print(f"\nIntercept: {weights['intercept']:+.4f}")
print(f"Best alpha: {weights['model_alpha']}")
print(f"CV R²: {weights['cv_r2_mean']:.3f} (+/- {weights['cv_r2_std']:.3f})")
print(f"Training samples: {weights['n_training_samples']}")
# Out:
# Feature coefficients (sorted by absolute magnitude):
#
# dg_pred_win_pct          : +21.5597  ████████████████████████████████████████
# long_approach_sg         : +3.6430  ██████████
# prior_augusta_sg         : +0.1975
# prior_appearances        : +0.1348
# driving_dist_vs_avg      : +0.0249
#
# Intercept: -0.9656
# Best alpha: 100.0
# CV R²: 0.149 (+/- 0.036)
# Training samples: 448
